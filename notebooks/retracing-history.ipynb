# %%
import wikivision

# %%
wikivision.graph_article_revisions('splendid_fairywren', labels=True)

# %%
wikivision.graph_article_revisions('splendid_fairywren', highlight=True, labels=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-c15368aa0901> in <module>()
# ----> 1 wikivision.graph_article_revisions('splendid_fairywren', highlight=True, labels=True)
#
# /Users/work/Research/Wikipedia/code/wikivision/wikivision/view.py in graph_article_revisions(article_slug, highlight, labels)
#      10
#      11     edges = revisions[['parent_sha1', 'rev_sha1']].iloc[1:]
# ---> 12     nodes = format_nodes(revisions, highlight=highlight)
#      13
#      14     remove_labels = not labels
#
# /Users/work/Research/Wikipedia/code/wikivision/wikivision/view.py in format_nodes(revisions, highlight)
#      65
#      66         nodes['style'] = 'filled'
# ---> 67         nodes['color'] = nodes.rev_type.apply(lambda x: rev_type_color[x])
#      68
#      69     nodes.drop('rev_type', axis=1, inplace=True)
#
# ...
